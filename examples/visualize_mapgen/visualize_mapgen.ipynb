# %%
# !pip install git+https://github.com/djps/k-wave-python.git@mapgen_plotting
# Out:
# ...
#   Cloning https://github.com/djps/k-wave-python.git (to revision mapgen_plotting) to /tmp/pip-req-build-wq0jkq4y
#   Running command git clone --filter=blob:none --quiet https://github.com/djps/k-wave-python.git /tmp/pip-req-build-wq0jkq4y
#   Running command git checkout -b mapgen_plotting --track origin/mapgen_plotting
#   Switched to a new branch 'mapgen_plotting'
#   Branch 'mapgen_plotting' set up to track remote branch 'mapgen_plotting' from 'origin'.
#   Resolved https://github.com/djps/k-wave-python.git to commit 77c655d78f1a431eb590f639d54392382619680a
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

from kwave.data import Vector
from kwave.kgrid import kWaveGrid
from kwave.utils.data import scale_SI
from kwave.utils.mapgen import make_cart_rect

# %% [markdown]
# # Cart Rect
#
# This takes the data from one of the test examples.

# %%
rect_pos = [20, 20, 30]
Lx = 10
Ly = 10
theta = [70, 50, 20]
num_points = 500

npts_x = math.ceil(np.sqrt(num_points * Lx / Ly))
npts_y = math.ceil(num_points / npts_x)

data = make_cart_rect(rect_pos, Lx, Ly, theta=theta, num_points=num_points, plot_rect=True)

print(np.shape(data))
# Out:
# (3, 506)
